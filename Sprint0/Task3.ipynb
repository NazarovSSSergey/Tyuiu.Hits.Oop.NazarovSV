// %% [markdown]
// <h1 style="color:DodgerBlue">Индивидальный проект</h1>

// %% [markdown]
// <h2 style="color:DodgerBlue">Название проекта:</h2>
//
// ----
//
// ### Вариант задания 9

// %% [markdown]
// <h2 style="color:DodgerBlue">Описание проекта:</h2>
//
// ----
// Описание задачи: Создать базовый класс Order в C#, который будет представлять информацию о
// заказах товаров или услуг. На основе этого класса разработать 2-3 производных
// класса, демонстрирующих принципы наследования и полиморфизма. В каждом из
// классов должны быть реализованы новые атрибуты и методы, а также
// переопределены некоторые методы базового класса для демонстрации
// полиморфизма.
//
// 1. ОнлайнЗаказ (OnlineOrder): Должен содержать дополнительные атрибуты,
// такие как Email клиента (CustomerEmail). Метод AddItem() должен быть
// переопределен для добавления информации о способе доставки при
// добавлении элемента.
// 2. ФизическийЗаказ (PhysicalOrder): Должен содержать дополнительные
// атрибуты, такие как Адрес доставки (DeliveryAddress).
// Метод RemoveItem() должен быть переопределен для добавления
// информации о возврате товара при удалении элемента.
// 3. СпециализированныйЗаказ (SpecializedOrder) (если требуется третий класс):
// Должен содержать дополнительные атрибуты, такие как Специальные
// условия (SpecialConditions). Метод CalculateTotal() должен быть
// переопределен для учета специальных условий при расчете общей суммы
// заказа.

// %% [markdown]
// <h2 style="color:DodgerBlue">Реализация:</h2>
//
// ----

// %%
using System;
using System.Collections.Generic;

public class Item
{
    public string Name { get; set; }
    public decimal Price { get; set; }

    public Item(string name, decimal price)
    {
        Name = name;
        Price = price;
    }
}

public class Order
{
    public int OrderId { get; set; }
    public DateTime CreationDate { get; set; }
    public decimal TotalAmount { get; set; }
    
    public List<Item> Items { get; set; } = new List<Item>();

    public Order(int orderId)
    {
        OrderId = orderId;
        CreationDate = DateTime.Now;
        TotalAmount = 0;
    }

    public virtual decimal CalculateTotal()
    {
        decimal total = 0;
        foreach (var item in Items)
        {
            total += item.Price;
        }
        TotalAmount = total;
        return TotalAmount;
    }

    public virtual void AddItem(Item item)
    {
        Items.Add(item);
        CalculateTotal();
        Console.WriteLine($"Добавлен товар: {item.Name} ({item.Price:C})");
    }

    public virtual void RemoveItem(Item item)
    {
        if (Items.Remove(item))
        {
            CalculateTotal();
            Console.WriteLine($"Удален товар: {item.Name}");
        }
    }
}

public class OnlineOrder : Order
{
    public string CustomerEmail { get; set; }
    public string DeliveryMethod { get; set; }

    public OnlineOrder(int orderId, string customerEmail, string deliveryMethod) : base(orderId)
    {
        CustomerEmail = customerEmail;
        DeliveryMethod = deliveryMethod;
    }

    public override void AddItem(Item item)
    {
        base.AddItem(item);
        Console.WriteLine($"  [Онлайн-Заказ №{OrderId}] Способ доставки: {DeliveryMethod} | Email клиента: {CustomerEmail}");
    }
}

public class PhysicalOrder : Order
{
    public string DeliveryAddress { get; set; }

    public PhysicalOrder(int orderId, string deliveryAddress) : base(orderId)
    {
        DeliveryAddress = deliveryAddress;
    }

    public override void RemoveItem(Item item)
    {
        base.RemoveItem(item);
        Console.WriteLine($"  [Физический Заказ №{OrderId}] Товар возвращен в пункте выдачи/магазине: {DeliveryAddress}");
    }
}

public class SpecializedOrder : Order
{
    public string SpecialConditions { get; set; }
    public decimal DiscountAmount { get; set; }

    public SpecializedOrder(int orderId, string specialConditions, decimal discountAmount) : base(orderId)
    {
        SpecialConditions = specialConditions;
        DiscountAmount = discountAmount;
    }

    public override decimal CalculateTotal()
    {
        decimal baseTotal = base.CalculateTotal();
        TotalAmount = baseTotal - DiscountAmount;
        if (TotalAmount < 0) TotalAmount = 0;
        return TotalAmount;
    }
}

class Program
{
    static void Main()
    {
        Console.WriteLine("=== Демонстрация работы заказов (ООП) ===\n");

        Item item1 = new Item("Клавиатура", 3000);
        Item item2 = new Item("Мышь", 1500);
        Item item3 = new Item("Монитор", 15000);

        Order[] orders = new Order[]
        {
            new OnlineOrder(1, "client@gmail.com", "Курьерская доставка"),
            new PhysicalOrder(2, "г. Москва, ул. Ленина, д. 5"),
            new SpecializedOrder(3, "Скидка постоянного клиента", 1000)
        };

        foreach (var order in orders)
        {
            Console.WriteLine(new string('═', 55));
            Console.WriteLine($"Обработка заказа ID: {order.OrderId} от {order.CreationDate:dd.MM.yyyy HH:mm}");
            Console.WriteLine();

            order.AddItem(item1);
            order.AddItem(item2);

            if (order is SpecializedOrder specOrder)
            {
                Console.WriteLine($"  [Спец-условия]: {specOrder.SpecialConditions}");
                Console.WriteLine($"  [Скидка]: {specOrder.DiscountAmount:C}");
            }

            Console.WriteLine($"Итоговая сумма заказа: {order.CalculateTotal():C}\n");

            order.RemoveItem(item1);
            Console.WriteLine($"Сумма после удаления: {order.TotalAmount:C}\n");
        }
    }
}
